# %%
with open("miracle_in_the_andes.txt","r",encoding = "UTF-8") as file:
    book = file.read()

# %% [markdown]
# # The most used words(non-articles)

# %%
import re
pattern = re.compile("[a-zA-Z]+")
findings = re.findall(pattern,book.lower())
len(findings)
# Out:
# 86798

# %%
d ={}
for word in findings:
    if word in d.keys():
        d[word] = d[word] +1
    else:
        d[word] = 1

# %%
d_list = [(value,key) for (key,value) in d.items()]
sorted(d_list, reverse = True)
d_list[:5]
# Out:
# [(11, 'chapter'), (93, 'before'), (800, 'it'), (1430, 'was'), (1, 'friday')]

# %%
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
english_stopwords = stopwords.words("english")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\urvic\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
filtered_words = []
for count,word in d_list:
    if word not in english_stopwords:
        filtered_words.append((word, count))

# %%
filtered_words
# Out:
# [('chapter', 11),
#  ('friday', 1),
#  ('thirteenth', 1),
#  ('october', 8),
#  ('joked', 3),
#  ('flying', 15),
#  ('andes', 79),
#  ('unlucky', 1),
#  ('day', 88),
#  ('young', 34),
#  ('men', 23),
#  ('make', 88),
#  ('kinds', 3),
#  ('jokes', 3),
#  ('easily', 8),
#  ('flight', 26),
#  ('originated', 1),
#  ('one', 249),
#  ('earlier', 9),
#  ('montevideo', 27),
#  ('hometown', 1),
#  ('destination', 2),
#  ('santiago', 21),
#  ('chile', 26),
#  ('chartered', 2),
#  ('fairchild', 75),
#  ('twin', 1),
#  ('engine', 5),
#  ('turboprop', 1),
#  ('carrying', 5),
#  ('rugby', 49),
#  ('team', 50),
#  ('old', 51),
#  ('christians', 19),
#  ('club', 5),
#  ('play', 19),
#  ('exhibition', 2),
#  ('match', 14),
#  ('top', 26),
#  ('chilean', 20),
#  ('squad', 4),
#  ('forty', 5),
#  ('five', 21),
#  ('people', 30),
#  ('aboard', 1),
#  ('including', 13),
#  ('four', 15),
#  ('crew', 10),
#  ('members', 10),
#  ('pilot', 12),
#  ('copilot', 11),
#  ('mechanic', 7),
#  ('steward', 5),
#  ('passengers', 11),
#  ('teammates', 9),
#  ('also', 44),
#  ('accompanied', 1),
#  ('friends', 83),
#  ('family', 38),
#  ('supporters', 5),
#  ('mother', 92),
#  ('eugenia', 6),
#  ('younger', 7),
#  ('sister', 45),
#  ('susy', 70),
#  ('sitting', 17),
#  ('across', 39),
#  ('aisle', 5),
#  ('row', 13),
#  ('front', 24),
#  ('original', 1),
#  ('itinerary', 1),
#  ('fly', 20),
#  ('nonstop', 1),
#  ('trip', 29),
#  ('three', 49),
#  ('half', 26),
#  ('hours', 80),
#  ('reports', 5),
#  ('bad', 15),
#  ('weather', 21),
#  ('mountains', 147),
#  ('ahead', 30),
#  ('forced', 40),
#  ('julio', 1),
#  ('ferradas', 7),
#  ('put', 14),
#  ('plane', 116),
#  ('spanish', 3),
#  ('colonial', 1),
#  ('town', 6),
#  ('mendoza', 15),
#  ('lies', 8),
#  ('east', 20),
#  ('andean', 8),
#  ('foothills', 9),
#  ('landed', 5),
#  ('lunchtime', 1),
#  ('hopes', 20),
#  ('would', 575),
#  ('back', 115),
#  ('air', 73),
#  ('encouraging', 1),
#  ('soon', 77),
#  ('clear', 36),
#  ('stay', 34),
#  ('night', 105),
#  ('none', 20),
#  ('us', 519),
#  ('liked', 10),
#  ('idea', 22),
#  ('losing', 8),
#  ('charming', 1),
#  ('place', 76),
#  ('decided', 30),
#  ('best', 36),
#  ('time', 182),
#  ('guys', 17),
#  ('relaxed', 2),
#  ('sidewalk', 4),
#  ('caf', 3),
#  ('along', 32),
#  ('broad', 14),
#  ('tree', 3),
#  ('lined', 1),
#  ('boulevards', 1),
#  ('went', 31),
#  ('sightseeing', 1),
#  ('city', 7),
#  ('historic', 2),
#  ('neighborhoods', 2),
#  ('spent', 38),
#  ('afternoon', 39),
#  ('watching', 17),
#  ('auto', 4),
#  ('race', 12),
#  ('track', 6),
#  ('outside', 34),
#  ('evening', 14),
#  ('movie', 4),
#  ('others', 126),
#  ('dancing', 3),
#  ('argentinean', 1),
#  ('girls', 25),
#  ('met', 16),
#  ('exploring', 1),
#  ('quaint', 1),
#  ('gift', 3),
#  ('shops', 1),
#  ('buying', 2),
#  ('presents', 1),
#  ('souvenirs', 1),
#  ('home', 67),
#  ('especially', 19),
#  ('pleased', 1),
#  ('find', 78),
#  ('pair', 6),
#  ('red', 8),
#  ('baby', 8),
#  ('shoes', 16),
#  ('small', 62),
#  ('boutique', 1),
#  ('thought', 106),
#  ('perfect', 13),
#  ('graciela', 13),
#  ('new', 30),
#  ('boy', 20),
#  ('slept', 16),
#  ('late', 24),
#  ('next', 36),
#  ('morning', 70),
#  ('woke', 12),
#  ('anxious', 3),
#  ('leave', 42),
#  ('still', 137),
#  ('word', 5),
#  ('departure', 7),
#  ('separate', 2),
#  ('ways', 17),
#  ('see', 115),
#  ('little', 60),
#  ('finally', 49),
#  ('received', 2),
#  ('gather', 7),
#  ('airport', 6),
#  ('p', 3),
#  ('sharp', 13),
#  ('arrived', 14),
#  ('discover', 1),
#  ('dante', 2),
#  ('lagurara', 12),
#  ('yet', 14),
#  ('whether', 6),
#  ('reacted', 1),
#  ('news', 27),
#  ('frustration', 3),
#  ('anger', 10),
#  ('understood', 38),
#  ('difficult', 24),
#  ('decision', 11),
#  ('confronting', 1),
#  ('pilots', 22),
#  ('warned', 1),
#  ('turbulence', 7),
#  ('path', 34),
#  ('speaking', 10),
#  ('cargo', 3),
#  ('flown', 5),
#  ('confident', 4),
#  ('could', 252),
#  ('safely', 10),
#  ('troubling', 2),
#  ('problem', 5),
#  ('already', 39),
#  ('early', 22),
#  ('boarded', 4),
#  ('necessary', 1),
#  ('arrangements', 1),
#  ('made', 104),
#  ('officials', 5),
#  ('well', 47),
#  ('past', 19),
#  ('two', 78),
#  ('clock', 7),
#  ('warm', 48),
#  ('rises', 1),
#  ('argentine', 9),
#  ('meets', 1),
#  ('frigid', 16),
#  ('snowline', 2),
#  ('create', 4),
#  ('treacherous', 5),
#  ('instability', 1),
#  ('atmosphere', 6),
#  ('knew', 155),
#  ('dangerous', 8),
#  ('way', 164),
#  ('predict', 1),
#  ('swirling', 6),
#  ('currents', 2),
#  ('might', 57),
#  ('strike', 2),
#  ('got', 15),
#  ('hold', 31),
#  ('tossed', 7),
#  ('around', 88),
#  ('like', 165),
#  ('toy', 1),
#  ('hand', 18),
#  ('aircraft', 10),
#  ('f', 3),
#  ('leased', 2),
#  ('uruguayan', 15),
#  ('force', 37),
#  ('laws', 2),
#  ('argentina', 8),
#  ('forbade', 2),
#  ('foreign', 1),
#  ('military', 6),
#  ('soil', 2),
#  ('longer', 35),
#  ('twenty', 20),
#  ('since', 43),
#  ('almost', 27),
#  ('fast', 18),
#  ('take', 60),
#  ('brave', 11),
#  ('skies', 12),
#  ('end', 34),
#  ('vacation', 2),
#  ('pondered', 2),
#  ('options', 2),
#  ('impatience', 2),
#  ('grew', 37),
#  ('lost', 57),
#  ('frustrated', 1),
#  ('bold', 2),
#  ('fearless', 1),
#  ('full', 16),
#  ('angered', 2),
#  ('slipping', 9),
#  ('away', 78),
#  ('regarded', 1),
#  ('timidity', 1),
#  ('hide', 3),
#  ('feelings', 7),
#  ('saw', 117),
#  ('jeered', 1),
#  ('whistled', 1),
#  ('teased', 2),
#  ('questioned', 2),
#  ('competence', 1),
#  ('hired', 3),
#  ('someone', 48),
#  ('shouted', 34),
#  ('want', 39),
#  ('know', 100),
#  ('behavior', 4),
#  ('influenced', 1),
#  ('seem', 10),
#  ('unsettle', 1),
#  ('last', 61),
#  ('consultation', 1),
#  ('glanced', 22),
#  ('crowd', 3),
#  ('waiting', 29),
#  ('restlessly', 2),
#  ('answer', 12),
#  ('announced', 5),
#  ('continue', 8),
#  ('greeted', 2),
#  ('rowdy', 1),
#  ('cheer', 1),
#  ('departed', 2),
#  ('eighteen', 4),
#  ('minutes', 14),
#  ('local', 2),
#  ('climbed', 38),
#  ('banked', 4),
#  ('steeply', 4),
#  ('left', 83),
#  ('turn', 20),
#  ('south', 16),
#  ('rising', 12),
#  ('right', 68),
#  ('western', 14),
#  ('horizon', 8),
#  ('windows', 8),
#  ('side', 49),
#  ('fuselage', 140),
#  ('gazed', 9),
#  ('thundered', 3),
#  ('dry', 10),
#  ('plateau', 4),
#  ('black', 22),
#  ('mirage', 1),
#  ('bleak', 2),
#  ('majestic', 3),
#  ('astonishingly', 1),
#  ('vast', 7),
#  ('huge', 16),
#  ('simple', 27),
#  ('sight', 10),
#  ('heart', 52),
#  ('rooted', 1),
#  ('massive', 8),
#  ('swells', 1),
#  ('bedrock', 1),
#  ('colossal', 4),
#  ('bases', 2),
#  ('spread', 13),
#  ('miles', 18),
#  ('ridges', 21),
#  ('soared', 3),
#  ('flatlands', 1),
#  ('peak', 6),
#  ('crowding', 1),
#  ('seemed', 84),
#  ('form', 11),
#  ('fortress', 2),
#  ('wall', 37),
#  ('poetically', 1),
#  ('inclined', 1),
#  ('man', 50),
#  ('warning', 2),
#  ('great', 59),
#  ('authority', 3),
#  ('held', 15),
#  ('ground', 26),
#  ('impossible', 23),
#  ('think', 77),
#  ('living', 31),
#  ('things', 58),
#  ('minds', 4),
#  ('hearts', 5),
#  ('brooding', 2),
#  ('awareness', 2),
#  ('wonder', 5),
#  ('ancients', 1),
#  ('holy', 3),
#  ('places', 15),
#  ('doorstep', 1),
#  ('heaven', 3),
#  ('dwelling', 2),
#  ('gods', 1),
#  ('uruguay', 24),
#  ('low', 13),
#  ('lying', 40),
#  ('country', 13),
#  ('knowledge', 8),
#  ('limited', 2),
#  ('read', 5),
#  ('books', 7),
#  ('school', 26),
#  ('learned', 15),
#  ('range', 4),
#  ('extensive', 1),
#  ('mountain', 183),
#  ('system', 7),
#  ('world', 52),
#  ('running', 14),
#  ('length', 3),
#  ('america', 5),
#  ('venezuela', 1),
#  ('north', 4),
#  ('southern', 3),
#  ('tip', 6),
#  ('continent', 1),
#  ('tierra', 1),
#  ('del', 16),
#  ('fuego', 1),
#  ('second', 50),
#  ('highest', 6),
#  ('planet', 3),
#  ('terms', 3),
#  ('average', 2),
#  ('elevation', 1),
#  ('himalayas', 1),
#  ('higher', 6),
#  ('heard', 47),
#  ('refer', 2),
#  ('earth', 9),
#  ('geological', 1),
#  ('wonders', 3),
#  ('view', 16),
#  ('airplane', 6),
#  ('gave', 48),
#  ('visceral', 2),
#  ('understanding', 4),
#  ('meant', 8),
#  ('west', 49),
#  ('sprawled', 1),
#  ('far', 50),
#  ('eye', 16),
#  ('even', 106),
#  ('though', 23),
#  ('many', 89),
#  ('height', 4),
#  ('mass', 2),
#  ('impassable', 5),
#  ('fact', 31),
#  ('concerned', 6),
#  ('exactly', 7),
#  ('due', 2),
#  ('region', 4),
#  ('separates', 1),
#  ('cities', 2),
#  ('sections', 1),
#  ('entire', 6),
#  ('chain', 2),
#  ('tallest', 4),
#  ('somewhere', 13),
#  ('example', 14),
#  ('aconcagua', 1),
#  ('hemisphere', 2),
#  ('seven', 10),
#  ('summit', 25),
#  ('feet', 93),
#  ('stands', 2),
#  ('shy', 3),
#  ('everest', 1),
#  ('giants', 1),
#  ('neighbors', 5),
#  ('foot', 22),
#  ('mount', 6),
#  ('mercedario', 1),
#  ('tupongato', 1),
#  ('tall', 14),
#  ('surrounding', 5),
#  ('behemoths', 1),
#  ('peaks', 18),
#  ('elevations', 1),
#  ('wild', 11),
#  ('reaches', 2),
#  ('ever', 40),
#  ('bothered', 2),
#  ('name', 8),
#  ('towering', 4),
#  ('summits', 6),
#  ('chance', 32),
#  ('maximum', 1),
#  ('cruising', 2),
#  ('altitude', 26),
#  ('direct', 4),
#  ('route', 17),
#  ('instead', 15),
#  ('charted', 1),
#  ('course', 20),
#  ('hundred', 23),
#  ('planch', 5),
#  ('n', 17),
#  ('pass', 14),
#  ('narrow', 12),
#  ('corridor', 1),
#  ('enough', 62),
#  ('eastern', 9),
#  ('always', 78),
#  ('reached', 34),
#  ('weave', 4),
#  ('cleared', 6),
#  ('hour', 20),
#  ('dark', 29),
#  ('first', 121),
#  ('leg', 19),
#  ('calm', 17),
#  ('less', 13),
#  ('vicinity', 1),
#  ('details', 6),
#  ('help', 49),
#  ('noticing', 3),
#  ('distance', 25),
#  ('directly', 6),
#  ('cordillera', 17),
#  ('window', 12),
#  ('seat', 34),
#  ('watched', 16),
#  ('flat', 10),
#  ('featureless', 1),
#  ('landscape', 7),
#  ('leap', 3),
#  ('rugged', 9),
#  ('heaving', 3),
#  ('buckling', 1),
#  ('awesome', 4),
#  ('convolutions', 1),
#  ('true', 23),
#  ('shark', 1),
#  ('finned', 1),
#  ('raised', 9),
#  ('soaring', 3),
#  ('sails', 1),
#  ('menacing', 1),
#  ('pushed', 12),
#  ('gigantic', 3),
#  ('spearheads', 1),
#  ('broken', 21),
#  ('blades', 4),
#  ('hatchets', 1),
#  ('glacial', 2),
#  ('valleys', 3),
#  ('gashed', 2),
#  ('steep', 28),
#  ('slopes', 68),
#  ('forming', 1),
#  ('rows', 3),
#  ('deep', 46),
#  ('winding', 7),
#  ('snow', 227),
#  ('packed', 17),
#  ('corridors', 1),
#  ('stacked', 6),
#  ('folded', 2),
#  ('upon', 11),
#  ('endless', 8),
#  ('maze', 2),
#  ('ice', 23),
#  ('rock', 63),
#  ('winter', 5),
#  ('given', 23),
#  ('spring', 6),
#  ('temperatures', 13),
#  ('routinely', 2),
#  ('dipped', 4),
#  ('degrees', 5),
#  ('zero', 4),
#  ('fahrenheit', 1),
#  ('desert', 2),
#  ('avalanches', 2),
#  ('blizzards', 3),
#  ('killing', 5),
#  ('gale', 1),
#  ('winds', 15),
#  ('common', 8),
#  ('previous', 5),
#  ('severe', 8),
#  ('record', 1),
#  ('snowfalls', 1),
#  ('several', 21),
#  ('color', 3),
#  ('muted', 3),
#  ('patches', 4),
#  ('gray', 8),
#  ('softness', 5),
#  ('life', 161),
#  ('looked', 58),
#  ('wildness', 2),
#  ('laugh', 3),
#  ('arrogance', 2),
#  ('anyone', 23),
#  ('human', 36),
#  ('beings', 4),
#  ('conquered', 4),
#  ('noticed', 7),
#  ('wisps', 1),
#  ('fog', 8),
#  ('gathering', 8),
#  ('felt', 127),
#  ('shoulder', 8),
#  ('switch', 1),
#  ('seats', 36),
#  ('nando', 64),
#  ('look', 45),
#  ('friend', 31),
#  ('panchito', 54),
#  ('beside', 29),
#  ('nodded', 29),
#  ('rose', 17),
#  ('stood', 18),
#  ('change', 13),
#  ('yelled', 1),
#  ('turned', 45),
#  ('catch', 6),
#  ('ball', 29),
#  ('rear', 11),
#  ('cabin', 12),
#  ('passed', 46),
#  ('forward', 54),
#  ('sank', 12),
#  ('laughing', 4),
#  ('talking', 11),
#  ('moving', 18),
#  ('visiting', 2),
#  ('oldest', 4),
#  ('amigo', 2),
#  ('guido', 14),
#  ('magri', 5),
#  ('playing', 18),
#  ('cards', 3),
#  ('began', 97),
#  ('bouncing', 3),
#  ('stepped', 10),
#  ('tried', 55),
#  ('settle', 2),
#  ('please', 22),
#  ('players', 13),
#  ('traveling', 6),
#  ('teams', 6),
#  ('took', 65),
#  ('regular', 2),
#  ('matches', 5),
#  ('seriously', 8),
#  ('really', 18),
#  ('holiday', 2),
#  ('feeling', 17),
#  ('begun', 7),
#  ('fine', 13),
#  ('thing', 31),
#  ('much', 97),
#  ('together', 46),
#  ('years', 42),
#  ('learning', 2),
#  ('training', 3),
#  ('heartbreaking', 2),
#  ('losses', 5),
#  ('hard', 76),
#  ('fought', 10),
#  ('wins', 1),
#  ('grown', 12),
#  ('drawing', 8),
#  ('strengths', 2),
#  ('trust', 18),
#  ('another', 66),
#  ('pressure', 7),
#  ('game', 35),
#  ('shaped', 7),
#  ('friendships', 5),
#  ('characters', 2),
#  ('brought', 20),
#  ('brothers', 25),
#  ('known', 14),
#  ('ten', 17),
#  ('days', 77),
#  ('schoolboy', 1),
#  ('ruggers', 2),
#  ('guidance', 5),
#  ('irish', 3),
#  ('christian', 17),
#  ('stella', 11),
#  ('maris', 11),
#  ('come', 64),
#  ('ireland', 1),
#  ('invitation', 4),
#  ('group', 29),
#  ('catholic', 9),
#  ('parents', 17),
#  ('wanted', 52),
#  ('found', 126),
#  ('private', 5),
#  ('answered', 20),
#  ('call', 13),
#  ('created', 6),
#  ('college', 3),
#  ('boys', 42),
#  ('ages', 2),
#  ('nine', 5),
#  ('sixteen', 6),
#  ('located', 2),
#  ('carrasco', 10),
#  ('neighborhood', 5),
#  ('students', 2),
#  ('lived', 17),
#  ('goal', 5),
#  ('education', 2),
#  ('build', 9),
#  ('character', 4),
#  ('intellect', 1),
#  ('teaching', 7),
#  ('methods', 1),
#  ('stressed', 1),
#  ('discipline', 5),
#  ('piety', 1),
#  ('selflessness', 4),
#  ('respect', 17),
#  ('promote', 1),
#  ('values', 4),
#  ('classroom', 1),
#  ('discouraged', 1),
#  ('natural', 10),
#  ('american', 3),
#  ('passion', 13),
#  ('soccer', 8),
#  ('fostered', 1),
#  ('selfishness', 1),
#  ('egotism', 1),
#  ('steered', 2),
#  ('toward', 49),
#  ('rougher', 1),
#  ('earthier', 1),
#  ('generations', 1),
#  ('virtually', 1),
#  ('unknown', 15),
#  ('strange', 6),
#  ('brutal', 7),
#  ('painful', 10),
#  ('pushing', 3),
#  ('shoving', 5),
#  ('wide', 13),
#  ('open', 31),
#  ('flair', 1),
#  ('firmly', 9),
#  ('believed', 12),
#  ('qualities', 1),
#  ('required', 14),
#  ('master', 1),
#  ('sport', 7),
#  ('characteristics', 1),
#  ('needed', 27),
#  ('live', 30),
#  ('decent', 3),
#  ('humility', 1),
#  ('tenacity', 2),
#  ('self', 18),
#  ('devotion', 1),
#  ('determined', 4),
#  ('long', 95),
#  ('learn', 2),
#  ('set', 34),
#  ('purpose', 8),
#  ('sway', 1),
#  ('aside', 4),
#  ('balls', 2),
#  ('acquainted', 1),
#  ('fat', 4),
#  ('pointed', 6),
#  ('pigskin', 1),
#  ('used', 20),
#  ('tough', 7),
#  ('practices', 1),
#  ('fields', 7),
#  ('behind', 41),
#  ('started', 18),
#  ('scratch', 4),
#  ('drilling', 1),
#  ('intricacies', 1),
#  ('mucks', 1),
#  ('rauls', 1),
#  ('scrumdowns', 1),
#  ('lineouts', 2),
#  ('kick', 4),
#  ('tackle', 1),
#  ('wore', 9),
#  ('pads', 1),
#  ('helmets', 1),
#  ('expected', 7),
#  ('aggressively', 2),
#  ('physical', 14),
#  ('courage', 34),
#  ('brute', 3),
#  ('strength', 72),
#  ('sound', 17),
#  ('strategy', 1),
#  ('quick', 7),
#  ('thinking', 36),
#  ('agility', 4),
#  ('demanded', 3),
#  ('develop', 2),
#  ('unshakeable', 1),
#  ('sense', 58),
#  ('explained', 12),
#  ('falls', 4),
#  ('knocked', 3),
#  ('becomes', 2),
#  ('grass', 6),
#  ('saying', 5),
#  ('downed', 1),
#  ('player', 6),
#  ('stomped', 2),
#  ('trampled', 1),
#  ('opposition', 3),
#  ('part', 24),
#  ('turf', 3),
#  ('taught', 16),
#  ('behave', 2),
#  ('teammate', 7),
#  ('must', 72),
#  ('become', 24),
#  ('protector', 1),
#  ('sacrifice', 1),
#  ('shield', 5),
#  ('count', 5),
#  ('level', 20),
#  ('moral', 1),
#  ('ironclad', 1),
#  ('belief', 6),
#  ('devoutly', 1),
#  ('importance', 4),
#  ('striving', 3),
#  ('suffering', 46),
#  ('sacrificing', 1),
#  ('pursuit', 3),
#  ('passionate', 3),
#  ('point', 34),
#  ('choice', 19),
#  ('believe', 25),
#  ('understand', 25),
#  ('deeply', 8),
#  ('simplest', 4),
#  ('object', 2),
#  ('gain', 2),
#  ('control', 18),
#  ('usually', 6),
#  ('combined', 1),
#  ('use', 27),
#  ('cunning', 1),
#  ('speed', 17),
#  ('passing', 7),
#  ('deftly', 1),
#  ('sprinting', 1),
#  ('advance', 1),
#  ('try', 29),
#  ('line', 28),
#  ('score', 3),
#  ('dazzling', 1),
#  ('pinpoint', 1),
#  ('passes', 2),
#  ('brilliant', 7),
#  ('evasive', 1),
#  ('maneuvers', 1),
#  ('essence', 3),
#  ('controlled', 2),
#  ('melee', 1),
#  ('scrum', 18),
#  ('signature', 1),
#  ('formation', 1),
#  ('scrummage', 1),
#  ('forms', 3),
#  ('tight', 5),
#  ('huddle', 6),
#  ('crouching', 3),
#  ('arms', 48),
#  ('interlocked', 1),
#  ('tightly', 3),
#  ('woven', 1),
#  ('wedge', 1),
#  ('scrums', 2),
#  ('square', 5),
#  ('butts', 1),
#  ('shoulders', 15),
#  ('rough', 4),
#  ('closed', 9),
#  ('circle', 4),
#  ('official', 1),
#  ('signal', 4),
#  ('rolled', 13),
#  ('tries', 1),
#  ('push', 7),
#  ('legs', 40),
#  ('pluck', 1),
#  ('free', 10),
#  ('start', 12),
#  ('attack', 4),
#  ('inside', 38),
#  ('ferocious', 2),
#  ('knees', 16),
#  ('knock', 3),
#  ('temples', 1),
#  ('elbows', 5),
#  ('jaws', 4),
#  ('shins', 1),
#  ('constantly', 17),
#  ('bloodied', 1),
#  ('kicks', 2),
#  ('heavy', 26),
#  ('cleated', 1),
#  ('raw', 5),
#  ('labor', 3),
#  ('everything', 32),
#  ('changes', 1),
#  ('lightning', 2),
#  ('clears', 1),
#  ('begins', 3),
#  ('agile', 1),
#  ('dodge', 2),
#  ('oncoming', 1),
#  ('defenders', 2),
#  ('field', 13),
#  ('dragged', 11),
#  ('fires', 3),
#  ('center', 15),
#  ('sidesteps', 1),
#  ('tackler', 4),
#  ('tripped', 2),
#  ('stumbles', 1),
#  ('trailing', 1),
#  ('winger', 5),
#  ('moves', 2),
#  ('crisply', 1),
#  ('flanker', 1),
#  ('slashing', 1),
#  ('spinning', 1),
#  ('diving', 1),
#  ('bulling', 1),
#  ('tacklers', 3),
#  ('drag', 4),
#  ('carriers', 1),
#  ('mauled', 1),
#  ('rucks', 2),
#  ('every', 74),
#  ('inch', 9),
#  ('battle', 2),
#  ('angle', 7),
#  ('daylight', 8),
#  ('final', 8),
#  ('burst', 3),
#  ('effort', 25),
#  ('dash', 2),
#  ('dive', 3),
#  ('plodding', 1),
#  ('grunt', 1),
#  ('work', 53),
#  ('dance', 2),
#  ('single', 12),
#  ('claim', 2),
#  ('credit', 2),
#  ('scored', 1),
#  ('accumulation', 1),
#  ('individual', 3),
#  ('matter', 22),
#  ('carried', 7),
#  ('glory', 2),
#  ('belongs', 1),
#  ('job', 11),
#  ('head', 62),
#  ('wedged', 2),
#  ('hips', 12),
#  ('butting', 2),
#  ('thighs', 1),
#  ('backsides', 2),
#  ('surge', 8),
#  ('remember', 21),
#  ('weight', 15),
#  ('opposing', 1),
#  ('seems', 9),
#  ('immense', 1),
#  ('budge', 4),
#  ('dig', 13),
#  ('endure', 10),
#  ('stalemate', 2),
#  ('refuse', 2),
#  ('quit', 5),
#  ('moments', 57),
#  ('extreme', 4),
#  ('exertion', 2),
#  ('straining', 2),
#  ('completely', 10),
#  ('extended', 2),
#  ('body', 59),
#  ('straight', 1),
#  ('parallel', 1),
#  ('hopelessly', 4),
#  ('solid', 6),
#  ('stone', 2),
#  ('sometimes', 32),
#  ('forever', 8),
#  ('positions', 4),
#  ('resistance', 6),
#  ('soften', 1),
#  ('miraculously', 3),
#  ('immovable', 1),
#  ('slowly', 24),
#  ...]

# %% [markdown]
# # Sentiment Analysis:Whtat is most positive and negative chapter?

# %% [markdown]
# ### An example

# %%
nltk.download("vader_lexicon")
from nltk.sentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\urvic\AppData\Roaming\nltk_data...

# %%
scores = analyzer.polarity_scores("How beautiful are trees, really love them.")

# %%
if scores["pos"] > scores["neg"]:
    print("It is a positive text")
else:
    print("It is a negative text")
# Out:
# It is a positive text

# %%
analyzer.polarity_scores(book)
# Out:
# {'neg': 0.116, 'neu': 0.76, 'pos': 0.125, 'compound': 1.0}

# %% [markdown]
# ### Chapter sentiment Analysis

# %%
import re
pattern = re.compile("Chapter [0-9]+")
chapters = re.split(pattern, book)

# %%
chapters = chapters[1:]

# %%
for nr, chapter in enumerate(chapters):
    scores = analyzer.polarity_scores(chapter)
    print(nr + 1, scores)
# Out:
# 1 {'neg': 0.061, 'neu': 0.779, 'pos': 0.16, 'compound': 1.0}
# 2 {'neg': 0.12, 'neu': 0.726, 'pos': 0.154, 'compound': 0.9991}
# 3 {'neg': 0.145, 'neu': 0.751, 'pos': 0.105, 'compound': -0.9999}
# 4 {'neg': 0.141, 'neu': 0.721, 'pos': 0.138, 'compound': -0.9963}
# 5 {'neg': 0.118, 'neu': 0.742, 'pos': 0.141, 'compound': 0.9997}
# 6 {'neg': 0.124, 'neu': 0.761, 'pos': 0.115, 'compound': -0.9979}
# 7 {'neg': 0.136, 'neu': 0.761, 'pos': 0.103, 'compound': -0.9999}
# 8 {'neg': 0.12, 'neu': 0.786, 'pos': 0.094, 'compound': -0.9998}
# 9 {'neg': 0.097, 'neu': 0.824, 'pos': 0.079, 'compound': -0.9996}
# 10 {'neg': 0.086, 'neu': 0.733, 'pos': 0.181, 'compound': 1.0}
